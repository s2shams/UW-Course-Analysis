# %%
import pandas as pd
import numpy as np
import ast

# %%
course_df = pd.read_csv("./data files/Raw/Course_data.csv")
prof_df = pd.read_csv("./data files/Raw/Prof_data.csv")

# %%
prof_df.head()
# Out:
#        Professor_Name  Course Liked_%  \
# 0  Lori Michelle Case  CS 115     77%
# 1     Naomi Nishimura  CS 115     70%
# 2         Troy Vasiga  CS 115     96%
# 3   Victoria Sakhnini  CS 115     85%
# 4        Sandy Graham  CS 115     74%
#
#                                    Professor_Reviews
# 0  ['clear prof', 'Lori is an awesome professor. ...
# 1  ['Not really engaging but helpful.', 'Definite...
# 2  ['One of the best CS teacher, his lecture is v...
# 3  ['Great prof. Explains concepts very well and ...
# 4  ['Clear in her explanations.', "Her clicker so...

# %%
course_df
# Out:
#      Course_Code                                Course_Name  \
# 0         CS 115         Introduction to Computer Science 1
# 1       MATH 135            Algebra for Honours Mathematics
# 2       ECON 101             Introduction to Microeconomics
# 3      PSYCH 101                    Introductory Psychology
# 4       MATH 137         Calculus 1 for Honours Mathematics
# ...          ...                                        ...
# 8910    GEOG 662  Transforming Canadian Resource Management
# 8911     ERS 625           Qualitative Methods in Geography
# 8912    HLTH 725                        Sociology of Health
# 8913      ME 655          Advanced Building Energy Analysis
# 8914    CIVE 630          Advanced Building Energy Analysis
#
#       Number_of_Ratings Number_of_Comments Useful Easy Liked  \
# 0                  2206                NaN    22%  11%   25%
# 1                  1555       338 comments    84%  43%   78%
# 2                  1398       264 comments    63%  70%   45%
# 3                  1084       229 comments    73%  66%   78%
# 4                  1036       211 comments    84%  56%   68%
# ...                 ...                ...    ...  ...   ...
# 8910                  0                  0      0    0     0
# 8911                  0                  0      0    0     0
# 8912                  0                  0      0    0     0
# 8913                  0                  0      0    0     0
# 8914                  0                  0      0    0     0
#
#                                          Course_Reviews  \
# 0     ['A bird course, easy to get 90+, but it is us...
# 1     ['Very easy and interesting course, no concept...
# 2     ['you can just google everything but its just ...
# 3     ["Super fun, engaging prof and the exams are l...
# 4     ['Easy course', 'The course itself is somewhat...
# ...                                                 ...
# 8910                                     ['No reviews']
# 8911                                     ['No reviews']
# 8912                                     ['No reviews']
# 8913                                     ['No reviews']
# 8914                                     ['No reviews']
#
#                                       Course_Enrollment
# 0     ['87/90', '83/90', '88/90', '68/90', '88/90', ...
# 1     ['55/60', '54/60', '52/60', '59/60', '52/60', ...
# 2     ['252/387', '364/387', '184/220', '189/220', '...
# 3     ['418/446', '430/446', '212/285', '142/160', '...
# 4     ['92/120', '93/120', '111/120', '104/120', '92...
# ...                                                 ...
# 8910                                        ['no data']
# 8911                                        ['no data']
# 8912                                        ['no data']
# 8913                                        ['no data']
# 8914                                        ['no data']
#
# [8915 rows x 9 columns]

# %% [markdown]
# ## Cleaning up the course related data

# %% [markdown]
# We have 6 faculties in total. Health, Math, Arts, Engineering, Environment and Science. But how many unique course codes do we have?

# %%
codes = course_df['Course_Code'].copy()
codes = codes.apply(lambda x: x.split(" ")[0])
codes.nunique()
# Out:
# 188

# %% [markdown]
# Since I don't see any way to automate the division of faculties, I had to do them manually. All these course codes were obtained through the undergraduate calendar. You can see the list yourself through here: https://uwaterloo.ca/academic-calendar/undergraduate-studies/catalog#/courses

# %%
Keys = ["Math", "Engineering", "Science", "Health", "Environment", "Arts", "Coop"]

eng = ["AE", "ARCH", "BME", "CHE", "CIVE", "CE" , "ECE", "ENVE", "GEOE", "GENE", "MSE", "ME", "MTE", "NE", "SE", "SYDE", "NANO"]

math = ["AFM", "ACTSC", "AMATH", "CO", "COMM", "CS", "CFM", "ECON", "PHYS", "PMATH", "STAT", "MATBUS", "MATH", "MTHEL", "ACC", "BE", "CM"]

sci = ["AVIA", "BIOL", "CHEM", "COGSCI", "EARTH", "GERON", "HUMSC", "MNS", "PHYS", "PLAN", "PSCI", "SCI", "SCBUS", "SOC", "SFM", "MSCI"]

arts = ["ANTH", "APPLS", "ARABIC", "ARTS", "ARBUS", "BLKST", "BASE", "BET", "BUS", "CDNST", "CHINA", "CMW", "CLAS", "COMMST", "CROAT", "CI", "DAC", "DUTCH", "EASIA", "ENGL", "EMLS", "FINE", "FR",
        "GSJ", "GER", "GBDA", "GRK", "HIST", "HRM", "HRTS", "INDENT", "INDG", "INNOV", "INDEV", "INTST", "ITAL", "ITALST", "JAPAN", "JS", "INTEG", "KOREA", "LAT",
       "LS", "MGMT", "MEDVL", "MENN", "MOHAWK", "MUSIC", "PACS", "PHIL", "PORT", "PSYCH", "RS", "RUSS", "REES", "SMF", "SDS", "SWREN", "SOCWK", "STV", "SPAN", "SI", "THPERF",
       "AHS", "VCULT", "ESL", "WS", "ASL", "DRAMA"]

env = ["ENVS", "ENBUS", "ERS", "GEOG"]

coop = ["COOP", "PD", "PDARCH", "PDPHRM", "WKRPT", "SPCOM"]

health = ["HEALTH", "HHUM", "KIN", "OPTOM", "PHARM", "HLTH", "REC", "PHS"]

department = dict(zip(Keys, [math, eng, sci, health, env, arts, coop]))
length = len(eng) + len(math) + len(sci) + len(arts) + len(env) + len(coop) + len(health)
length
# Out:
# 137

# %% [markdown]
# We're missing some course codes, let's see what they are

# %%
all_course_codes = eng + math + sci + arts + env + coop + health
missing_courses = []
for i in range(len(codes.unique())):
    code = codes.unique()[i]
    if code not in all_course_codes:
        missing_courses.append(code)
missing_courses
# Out:
# ['SEQ',
#  'UNIV',
#  'ACINTY',
#  'ISS',
#  'NATST',
#  'SVENT',
#  'KPE',
#  'ADMGT',
#  'ARCHL',
#  'COMST',
#  'CT',
#  'DEI',
#  'DM',
#  'EFAS',
#  'EVSY',
#  'FILM',
#  'GEMCC',
#  'GGOV',
#  'GLOBAL',
#  'HSG',
#  'INTTS',
#  'IS',
#  'LED',
#  'MI',
#  'NES',
#  'PDENG',
#  'POLSH',
#  'PS',
#  'QIC',
#  'RELC',
#  'SOCIN',
#  'SPD',
#  'SUSM',
#  'SWK',
#  'TAX',
#  'TN',
#  'TOUR',
#  'TS',
#  'UN',
#  'WATER',
#  'ELPE',
#  'RSCH',
#  'TPM',
#  'AB',
#  'UU',
#  'ASTRN',
#  'CULT',
#  'WHMIS',
#  'ECDEV',
#  'DATSC',
#  'FCIT',
#  'WIL',
#  'UCR']

# %% [markdown]
# Since these are not present in the latest list of courses in the undergraduate calendar, I will assume that they have been discontinued, and so they will not be added to the dictionary

# %%
for course in missing_courses:
    course_df = course_df[course_df["Course_Code"].str.contains(course)==False]
course_df
# Out:
#      Course_Code                                Course_Name  \
# 0         CS 115         Introduction to Computer Science 1
# 1       MATH 135            Algebra for Honours Mathematics
# 2       ECON 101             Introduction to Microeconomics
# 4       MATH 137         Calculus 1 for Honours Mathematics
# 5           PD 1                        Career Fundamentals
# ...          ...                                        ...
# 8910    GEOG 662  Transforming Canadian Resource Management
# 8911     ERS 625           Qualitative Methods in Geography
# 8912    HLTH 725                        Sociology of Health
# 8913      ME 655          Advanced Building Energy Analysis
# 8914    CIVE 630          Advanced Building Energy Analysis
#
#       Number_of_Ratings Number_of_Comments Useful Easy Liked  \
# 0                  2206                NaN    22%  11%   25%
# 1                  1555       338 comments    84%  43%   78%
# 2                  1398       264 comments    63%  70%   45%
# 4                  1036       211 comments    84%  56%   68%
# 5                  1000       189 comments    19%  80%    7%
# ...                 ...                ...    ...  ...   ...
# 8910                  0                  0      0    0     0
# 8911                  0                  0      0    0     0
# 8912                  0                  0      0    0     0
# 8913                  0                  0      0    0     0
# 8914                  0                  0      0    0     0
#
#                                          Course_Reviews  \
# 0     ['A bird course, easy to get 90+, but it is us...
# 1     ['Very easy and interesting course, no concept...
# 2     ['you can just google everything but its just ...
# 4     ['Easy course', 'The course itself is somewhat...
# 5     ['The only effect of this course is to add pre...
# ...                                                 ...
# 8910                                     ['No reviews']
# 8911                                     ['No reviews']
# 8912                                     ['No reviews']
# 8913                                     ['No reviews']
# 8914                                     ['No reviews']
#
#                                       Course_Enrollment
# 0     ['87/90', '83/90', '88/90', '68/90', '88/90', ...
# 1     ['55/60', '54/60', '52/60', '59/60', '52/60', ...
# 2     ['252/387', '364/387', '184/220', '189/220', '...
# 4     ['92/120', '93/120', '111/120', '104/120', '92...
# 5     ['1956/3500', '21/1000', '475/3500', '32/1000'...
# ...                                                 ...
# 8910                                        ['no data']
# 8911                                        ['no data']
# 8912                                        ['no data']
# 8913                                        ['no data']
# 8914                                        ['no data']
#
# [7442 rows x 9 columns]

# %%
course_df[course_df.isnull().any(axis=1)]
# Out:
#      Course_Code                                 Course_Name  \
# 0         CS 115          Introduction to Computer Science 1
# 383       SE 490                            Design Project 1
# 1257    BUS 352W  Introduction to Marketing Management (WLU)
# 1275    ENVE 115                              Linear Algebra
# 1317      AE 104                                 Mechanics 1
# ...          ...                                         ...
# 3303    ASL 201R                    American Sign Language 3
# 3310   PHARM 326             Institutional Pharmacy Practice
# 3312     KIN 492  Exercise Management for Chronic Conditions
# 3315      BE 660                                Negotiations
# 3327  EASIA 101R               Learning East Asian Languages
#
#       Number_of_Ratings Number_of_Comments Useful Easy Liked  \
# 0                  2206                NaN    22%  11%   25%
# 383                  55                NaN    64%  74%   62%
# 1257                 10         0 comments    NaN  NaN   40%
# 1275                  9         0 comments    NaN  NaN   22%
# 1317                  9         0 comments    NaN  NaN   78%
# ...                 ...                ...    ...  ...   ...
# 3303                  1         0 comments    NaN  NaN  100%
# 3310                  1         0 comments    NaN  NaN    0%
# 3312                  1         0 comments    NaN  NaN  100%
# 3315                  1         0 comments    NaN  NaN  100%
# 3327                  1         0 comments    NaN  NaN  100%
#
#                                          Course_Reviews  \
# 0     ['A bird course, easy to get 90+, but it is us...
# 383   ["The purpose of the course is just to show yo...
# 1257                                     ['No reviews']
# 1275                                     ['No reviews']
# 1317                                     ['No reviews']
# ...                                                 ...
# 3303                                     ['No reviews']
# 3310                                     ['No reviews']
# 3312                                     ['No reviews']
# 3315                                     ['No reviews']
# 3327                                     ['No reviews']
#
#                                       Course_Enrollment
# 0     ['87/90', '83/90', '88/90', '68/90', '88/90', ...
# 383                        ['85/100', '32/40', '30/30']
# 1257                                        ['no data']
# 1275  ['80/85', '80/85', '80/85', '51/85', '26/42', ...
# 1317  ['100/100', '52/50', '48/50', '100/100', '87/1...
# ...                                                 ...
# 3303                                           ['9/25']
# 3310                                        ['114/120']
# 3312                                            ['7/8']
# 3315                                   ['7/35', '0/70']
# 3327                                  ['8/40', '13/40']
#
# [276 rows x 9 columns]

# %% [markdown]
# After some inspection, the null values in the useful, easy and liked column is due to a different selector being used when the value is N/A, so we can fill those values with 0

# %%
course_df[['Useful', 'Easy', 'Liked']] = course_df[['Useful', 'Easy', 'Liked']].fillna('0%')
course_df.reset_index(drop=True, inplace=True)
course_df[course_df.isnull().any(axis=1)]
# Out:
#     Course_Code                         Course_Name  Number_of_Ratings  \
# 0        CS 115  Introduction to Computer Science 1               2206
# 366      SE 490                    Design Project 1                 55
#
#     Number_of_Comments Useful Easy Liked  \
# 0                  NaN    22%  11%   25%
# 366                NaN    64%  74%   62%
#
#                                         Course_Reviews  \
# 0    ['A bird course, easy to get 90+, but it is us...
# 366  ["The purpose of the course is just to show yo...
#
#                                      Course_Enrollment
# 0    ['87/90', '83/90', '88/90', '68/90', '88/90', ...
# 366                       ['85/100', '32/40', '30/30']

# %% [markdown]
# Now we can fix the number of comments by replacing it with the length of the list in course_reviews. Since it was saved as a csv, we have to use ast to convert it back to a list.

# %%
course_df['Course_Reviews'] = course_df['Course_Reviews'].apply(ast.literal_eval)
course_df['Course_Enrollment'] = course_df['Course_Enrollment'].apply(ast.literal_eval)

course_df.loc[course_df['Course_Code'] == 'CS 115', 'Number_of_Comments'] = len(course_df.loc[course_df['Course_Code'] == 'CS 115', 'Course_Reviews'].values[0])
course_df.loc[course_df['Course_Code'] == 'SE 490', 'Number_of_Comments'] = len(course_df.loc[course_df['Course_Code'] == 'SE 490', 'Course_Reviews'].values[0])
course_df.iloc[[0,366]]
# Out:
#     Course_Code                         Course_Name  Number_of_Ratings  \
# 0        CS 115  Introduction to Computer Science 1               2206
# 366      SE 490                    Design Project 1                 55
#
#     Number_of_Comments Useful Easy Liked  \
# 0                  114    22%  11%   25%
# 366                  7    64%  74%   62%
#
#                                         Course_Reviews  \
# 0    [A bird course, easy to get 90+, but it is use...
# 366  [The purpose of the course is just to show you...
#
#                                      Course_Enrollment
# 0    [87/90, 83/90, 88/90, 68/90, 88/90, 56/84, 88/...
# 366                             [85/100, 32/40, 30/30]

# %% [markdown]
# Replace the course enrollments with the number of students that have taken the course within the past 3-4 terms, we don't really need the course cap.

# %%
def add_enrollments(list):
    students = 0
    for lecture in list:
        if lecture != 'no data':
            students += int(lecture.split("/")[0])
    return students

course_df["Course_Enrollment"] = course_df["Course_Enrollment"].apply(add_enrollments)
course_df
# Out:
#      Course_Code                                Course_Name  \
# 0         CS 115         Introduction to Computer Science 1
# 1       MATH 135            Algebra for Honours Mathematics
# 2       ECON 101             Introduction to Microeconomics
# 3       MATH 137         Calculus 1 for Honours Mathematics
# 4           PD 1                        Career Fundamentals
# ...          ...                                        ...
# 7437    GEOG 662  Transforming Canadian Resource Management
# 7438     ERS 625           Qualitative Methods in Geography
# 7439    HLTH 725                        Sociology of Health
# 7440      ME 655          Advanced Building Energy Analysis
# 7441    CIVE 630          Advanced Building Energy Analysis
#
#       Number_of_Ratings Number_of_Comments Useful Easy Liked  \
# 0                  2206                114    22%  11%   25%
# 1                  1555       338 comments    84%  43%   78%
# 2                  1398       264 comments    63%  70%   45%
# 3                  1036       211 comments    84%  56%   68%
# 4                  1000       189 comments    19%  80%    7%
# ...                 ...                ...    ...  ...   ...
# 7437                  0                  0      0    0     0
# 7438                  0                  0      0    0     0
# 7439                  0                  0      0    0     0
# 7440                  0                  0      0    0     0
# 7441                  0                  0      0    0     0
#
#                                          Course_Reviews  Course_Enrollment
# 0     [A bird course, easy to get 90+, but it is use...               4359
# 1     [Very easy and interesting course, no concepts...               7597
# 2     [you can just google everything but its just f...               6247
# 3     [Easy course, The course itself is somewhat ea...               8237
# 4     [The only effect of this course is to add pres...               5790
# ...                                                 ...                ...
# 7437                                       [No reviews]                  0
# 7438                                       [No reviews]                  0
# 7439                                       [No reviews]                  0
# 7440                                       [No reviews]                  0
# 7441                                       [No reviews]                  0
#
# [7442 rows x 9 columns]

# %% [markdown]
# Now we replace the percentages with their actual values

# %%
course_df['Useful'] = course_df['Useful'].apply(lambda x: x.replace('%', ''))
course_df['Easy'] = course_df['Easy'].apply(lambda x: x.replace('%', ''))
course_df['Liked'] = course_df['Liked'].apply(lambda x: x.replace('%', ''))

for index, row in course_df.iterrows():
    course_df.loc[index, 'Useful'] = round((int(row['Useful'])/100) * int(row['Number_of_Ratings']))
    course_df.loc[index, 'Easy'] = round((int(row['Easy'])/100) * int(row['Number_of_Ratings']))
    course_df.loc[index, 'Liked'] = round((int(row['Liked'])/100) * int(row['Number_of_Ratings']))
     
course_df
# Out:
#      Course_Code                                Course_Name  \
# 0         CS 115         Introduction to Computer Science 1
# 1       MATH 135            Algebra for Honours Mathematics
# 2       ECON 101             Introduction to Microeconomics
# 3       MATH 137         Calculus 1 for Honours Mathematics
# 4           PD 1                        Career Fundamentals
# ...          ...                                        ...
# 7437    GEOG 662  Transforming Canadian Resource Management
# 7438     ERS 625           Qualitative Methods in Geography
# 7439    HLTH 725                        Sociology of Health
# 7440      ME 655          Advanced Building Energy Analysis
# 7441    CIVE 630          Advanced Building Energy Analysis
#
#       Number_of_Ratings Number_of_Comments Useful Easy Liked  \
# 0                  2206                114    485  243   552
# 1                  1555       338 comments   1306  669  1213
# 2                  1398       264 comments    881  979   629
# 3                  1036       211 comments    870  580   704
# 4                  1000       189 comments    190  800    70
# ...                 ...                ...    ...  ...   ...
# 7437                  0                  0      0    0     0
# 7438                  0                  0      0    0     0
# 7439                  0                  0      0    0     0
# 7440                  0                  0      0    0     0
# 7441                  0                  0      0    0     0
#
#                                          Course_Reviews  Course_Enrollment
# 0     [A bird course, easy to get 90+, but it is use...               4359
# 1     [Very easy and interesting course, no concepts...               7597
# 2     [you can just google everything but its just f...               6247
# 3     [Easy course, The course itself is somewhat ea...               8237
# 4     [The only effect of this course is to add pres...               5790
# ...                                                 ...                ...
# 7437                                       [No reviews]                  0
# 7438                                       [No reviews]                  0
# 7439                                       [No reviews]                  0
# 7440                                       [No reviews]                  0
# 7441                                       [No reviews]                  0
#
# [7442 rows x 9 columns]

# %% [markdown]
# Cleaning up redundant text

# %%
course_df['Number_of_Comments'] = course_df['Number_of_Comments'].apply(lambda x: str(x).replace(' comments', ''))
course_df
# Out:
#      Course_Code                                Course_Name  \
# 0         CS 115         Introduction to Computer Science 1
# 1       MATH 135            Algebra for Honours Mathematics
# 2       ECON 101             Introduction to Microeconomics
# 3       MATH 137         Calculus 1 for Honours Mathematics
# 4           PD 1                        Career Fundamentals
# ...          ...                                        ...
# 7437    GEOG 662  Transforming Canadian Resource Management
# 7438     ERS 625           Qualitative Methods in Geography
# 7439    HLTH 725                        Sociology of Health
# 7440      ME 655          Advanced Building Energy Analysis
# 7441    CIVE 630          Advanced Building Energy Analysis
#
#       Number_of_Ratings Number_of_Comments Useful Easy Liked  \
# 0                  2206                114    485  243   552
# 1                  1555                338   1306  669  1213
# 2                  1398                264    881  979   629
# 3                  1036                211    870  580   704
# 4                  1000                189    190  800    70
# ...                 ...                ...    ...  ...   ...
# 7437                  0                  0      0    0     0
# 7438                  0                  0      0    0     0
# 7439                  0                  0      0    0     0
# 7440                  0                  0      0    0     0
# 7441                  0                  0      0    0     0
#
#                                          Course_Reviews  Course_Enrollment
# 0     [A bird course, easy to get 90+, but it is use...               4359
# 1     [Very easy and interesting course, no concepts...               7597
# 2     [you can just google everything but its just f...               6247
# 3     [Easy course, The course itself is somewhat ea...               8237
# 4     [The only effect of this course is to add pres...               5790
# ...                                                 ...                ...
# 7437                                       [No reviews]                  0
# 7438                                       [No reviews]                  0
# 7439                                       [No reviews]                  0
# 7440                                       [No reviews]                  0
# 7441                                       [No reviews]                  0
#
# [7442 rows x 9 columns]

# %% [markdown]
# Seems clean enough, let's move onto the professor table

# %% [markdown]
# ## Cleaning up the professor data

# %%
prof_df.head()
# Out:
#        Professor_Name  Course Liked_%  \
# 0  Lori Michelle Case  CS 115     77%
# 1     Naomi Nishimura  CS 115     70%
# 2         Troy Vasiga  CS 115     96%
# 3   Victoria Sakhnini  CS 115     85%
# 4        Sandy Graham  CS 115     74%
#
#                                    Professor_Reviews
# 0  ['clear prof', 'Lori is an awesome professor. ...
# 1  ['Not really engaging but helpful.', 'Definite...
# 2  ['One of the best CS teacher, his lecture is v...
# 3  ['Great prof. Explains concepts very well and ...
# 4  ['Clear in her explanations.', "Her clicker so...

# %% [markdown]
# The name column contains duplicates, my objective is to combine all the data in one dataframe where the name column contains unique entries

# %%
prof_df.shape
# Out:
# (9100, 4)

# %%
prof_df['Professor_Reviews'] = prof_df['Professor_Reviews'].apply(ast.literal_eval)
prof_df['Professor_Name'].nunique()
# Out:
# 3575

# %%
# profs = pd.DataFrame(prof_df['Professor_Name'].unique().copy(), columns=['Professor_Name'])
# profs['Courses_Taught'] = pd.Series(dtype=object)
# profs['Professor_Reviews'] = pd.Series(dtype=object)
# profs['Liked'] = pd.Series(dtype=str)

# for index, prof in profs.iterrows():
#     course_list = []
#     reviews_list = []
#     name = profs.loc[index, 'Professor_Name']
    
#     for i in range(len(prof_df.loc[prof_df['Professor_Name'] == name])):
#         course = prof_df.loc[prof_df['Professor_Name'] == name, 'Course'].values[i]
#         reviews = prof_df.loc[prof_df['Professor_Name'] == name, 'Professor_Reviews'].values[i]
#         reviews_list.append(reviews)
#         course_list.append(course)
        
#     profs.loc[index, 'Courses_Taught'] = course_list
#     profs.loc[index, 'Professor_Reviews'] = reviews_list
#     profs.loc[index, 'Liked'] = prof_df.loc[prof_df['Professor_Name'] == name, 'Liked_%'].values[0]
# profs

# %% [markdown]
# Above code works, but it's a brute force method and takes longer than I'd want it to. Below is an implementation of the same functionality but using .groupby()

# %%
new_prof_df = prof_df.groupby('Professor_Name').agg(
{
    'Course':lambda x: list(x),
    'Professor_Reviews':lambda x: list(x),
    'Liked_%': 'first'
}).reset_index().copy()

new_prof_df = new_prof_df.rename(columns={'Professor_Name':'Professor', 'Course':'Courses_Taught'})
# Ok wow this is way faster lol

# %%
new_prof_df['Clear'] = pd.Series(dtype=str)
new_prof_df['Engaging']=pd.Series(dtype=str)
new_prof_df['Number_of_Comments']=pd.Series(dtype=str)
new_prof_df['Number_of_Ratings']= pd.Series(dtype=str)

# %% [markdown]
# So I noticed some data missing such as number of ratings and some more that might be useful. Will be adding that in using selenium

# %%
new_prof_df[new_prof_df.isnull().any(axis=1)]
# Out:
#                   Professor                   Courses_Taught  \
# 0               Aakar Gupta                         [CS 230]
# 1     Aaron Daniel Ettinger                       [PSCI 387]
# 2          Aaron Hutchinson                       [MATH 115]
# 3                 Aaron Kay           [PSYCH 253, PSYCH 395]
# 4               Aaron Smith  [MATH 115, MATH 211, PMATH 467]
# ...                     ...                              ...
# 3570         rebecca shantz                      [MUSIC 270]
# 3571       shahla Aliakbari           [AMATH 250, AMATH 351]
# 3572       shalah aliakbari                        [ECE 205]
# 3573                   tsen                       [CHEM 120]
# 3574          young ki yoon                         [NE 131]
#
#                                       Professor_Reviews Liked_% Clear  \
# 0     [[TA was more clear and engaging, Doesn't real...     20%   NaN
# 1     [[He knows his material and is not a strict pr...     91%   NaN
# 2     [[There aren't any lectures this term, so I ca...     90%   NaN
# 3     [[By far the best prof ive ever had. He is a g...    None   NaN
# 4     [[I believe our class was the first class he t...     80%   NaN
# ...                                                 ...     ...   ...
# 3570  [[She clearly outlines expectations before ass...    100%   NaN
# 3571  [[Assume everyone knows basic physics rules an...     47%   NaN
# 3572  [[The professor makes very little effort in en...     31%   NaN
# 3573  [[Very good prof considering I think he's new ...    100%   NaN
# 3574  [[Not that engaging, and not much detail on th...     82%   NaN
#
#      Engaging Number_of_Comments Number_of_Ratings
# 0         NaN                NaN               NaN
# 1         NaN                NaN               NaN
# 2         NaN                NaN               NaN
# 3         NaN                NaN               NaN
# 4         NaN                NaN               NaN
# ...       ...                ...               ...
# 3570      NaN                NaN               NaN
# 3571      NaN                NaN               NaN
# 3572      NaN                NaN               NaN
# 3573      NaN                NaN               NaN
# 3574      NaN                NaN               NaN
#
# [3575 rows x 8 columns]

# %% [markdown]
# The new data we get from selenium will probably replace some of these null values, will see if any further refining will be needed after obtaining the data

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
import re, string
from Helper_functions import *
import itertools

options = webdriver.ChromeOptions()
options.binary_location = './chrome-win64/chrome.exe'
driver = webdriver.Chrome(options=options)
pattern = re.compile('[^a-zA-Z]')

# %% [markdown]
# There's an issue with how the website formats names that have special characters in them. From some ovservations it seems the website is random and inconsistent. Some names have their special characters replaced by "_", sometimes it's removed completely, sometimes if there are more than one, only one of them is removed. In order to handle this situation, if a 404 page is reached, I will iterate over all possible combinations of a url with and without special characters, the code that handles that is below

# %%
def generate_urls(name):
    chars = list('abcdefghijklmnopqrstuvwxyz_')
    name = name.lower()
    # print(name)
    special_char = [char for char in name if char not in chars]
    # print(special_char)
    
    combinations = []
    for i in range(len(special_char) + 1):
        combinations.extend(itertools.combinations(special_char, i))
    
    combos = [list(sublist) for sublist in combinations]
    # print(combos)
    
    urls = []
    for combo in combos:
        urls.append(''.join([char for char in name if char not in combo]))
    # print(urls)
    if "-" in name:
        urls.append(name.replace("-", "_"))
    return urls

# %% [markdown]
# I've also noticed that sometimes the url uses a reversed version of the name so I have to take that into consideration now as well

# %%
for index, name in enumerate(new_prof_df['Professor']):
    # if index == 5:
    #     break
    try:
        _name = name.replace(" ", "_")
        #_name = pattern.sub('', _name)
        #_name = "Amit_M._Mehta"
        url = f'https://uwflow.com/professor/{_name}'
        driver.get(url)
        # weird looking xpath to make it case insensitive
        wait_for_element(driver, f"//*[contains(translate(text(), 'ABCDEFGHIJKLMNOPQRSTUVWXYZ', 'abcdefghijklmnopqrstuvwxyz'), '{name.lower().split(' ')[0]}') or contains(text(), \"That professor doesn't exist!\")]")

        if driver.find_elements(By.XPATH, "//*[contains(text(), \"That professor doesn't exist!\")]"):
            name_reversed_list = name.split(" ")
            name_reversed_list.reverse()
            reverse_name = ""
            for i, name in enumerate(name_reversed_list):
                reverse_name += name
                if i != len(name_reversed_list) - 1:
                    reverse_name += " "

            possible_urls = generate_urls(_name)
            possible_urls.append(pattern.sub('_', name))
            possible_urls.extend(generate_urls(reverse_name.replace(" ", "_")))
            possible_urls.append(pattern.sub('_', reverse_name))
            # print(name)
            for combination in possible_urls:
                url = f'https://uwflow.com/professor/{combination}'
                # print(url)
                # print(index)
                driver.get(url)
                wait_for_element(driver, f"//*[contains(text(), '{name}') or contains(text(), \"That professor doesn't exist!\")]")

                if not driver.find_elements(By.XPATH, "//*[contains(text(), \"That professor doesn't exist!\")]"):
                    break

        wait_for_element(driver, "(//div[contains(text(), 'Clear')]//following::div[contains(text(), '%') or contains(text(), 'N/A')][1])[1]")
        clear = driver.find_elements(By.XPATH, "(//div[contains(text(), 'Clear')]//following::div[contains(text(), '%') or contains(text(), 'N/A')][1])[1]")[0].text
        engaging = driver.find_elements(By.XPATH, "(//div[contains(text(), 'Engaging')]//following::div[contains(text(), '%') or contains(text(), 'N/A')][1])[1]")[0].text
        liked = driver.find_elements(By.XPATH, "(//div[contains(text(), 'liked')]//preceding::div[contains(text(), '%') or contains(text(), 'N/A')][1])[1]")[0].text

        wait_for_element(driver, "//a[contains(normalize-space(),'comments') or contains(normalize-space(), comment)]")
        if driver.find_elements(By.XPATH, "//a[contains(normalize-space(),'comments') or contains(normalize-space(), 'comment')]"):
            number_of_comments = driver.find_elements(By.XPATH, "//a[contains(normalize-space(),'comments') or contains(normalize-space(), 'comment')]")[0].text
        else:
            number_of_comments = 0
        wait_for_element(driver, "(//a[contains(normalize-space(),'comments') or contains(normalize-space(), 'comment')]//following::*[1])[1]")
        if driver.find_elements(By.XPATH, "(//a[contains(normalize-space(),'comments') or contains(normalize-space(), 'comment')]//following::*[1])[1]"):
            number_of_ratings = driver.find_elements(By.XPATH, "(//a[contains(normalize-space(),'comments') or contains(normalize-space(), 'comment')]//following::*[1])[1]")[0].text
        else:
            number_of_ratings = 0

        new_prof_df.loc[index, 'Clear'] = clear
        new_prof_df.loc[index, 'Engaging'] = engaging
        new_prof_df.loc[index, 'liked'] = liked
        new_prof_df.loc[index, 'Number_of_Ratings'] = number_of_ratings
        new_prof_df.loc[index, 'Number_of_Comments'] = number_of_comments

        time.sleep(.5)
    except Exception as e:
        # print(e)
        continue

driver.quit()
new_prof_df

# %% [markdown]
# Now I have to classify each course to what department it falls under. This will be done by checking what key it falls under in the department_dict

# %%
course_df['Department'] = pd.Series(dtype=str)

def generate_department(row, department_dict):
    course_code = str(row["Course_Code"]).split(" ")[0]
    
    for key in department_dict.keys():
        value = department_dict[f"{key}"]
        if course_code in value:
            return key
    return 'empty'

course_df['Department'] = course_df.apply(generate_department, department_dict=department, axis=1)
course_df
# Out:
#      Course_Code                                Course_Name  \
# 0         CS 115         Introduction to Computer Science 1
# 1       MATH 135            Algebra for Honours Mathematics
# 2       ECON 101             Introduction to Microeconomics
# 3       MATH 137         Calculus 1 for Honours Mathematics
# 4           PD 1                        Career Fundamentals
# ...          ...                                        ...
# 7437    GEOG 662  Transforming Canadian Resource Management
# 7438     ERS 625           Qualitative Methods in Geography
# 7439    HLTH 725                        Sociology of Health
# 7440      ME 655          Advanced Building Energy Analysis
# 7441    CIVE 630          Advanced Building Energy Analysis
#
#       Number_of_Ratings Number_of_Comments Useful Easy Liked  \
# 0                  2206                114    485  243   552
# 1                  1555                338   1306  669  1213
# 2                  1398                264    881  979   629
# 3                  1036                211    870  580   704
# 4                  1000                189    190  800    70
# ...                 ...                ...    ...  ...   ...
# 7437                  0                  0      0    0     0
# 7438                  0                  0      0    0     0
# 7439                  0                  0      0    0     0
# 7440                  0                  0      0    0     0
# 7441                  0                  0      0    0     0
#
#                                          Course_Reviews  Course_Enrollment  \
# 0     [A bird course, easy to get 90+, but it is use...               4359
# 1     [Very easy and interesting course, no concepts...               7597
# 2     [you can just google everything but its just f...               6247
# 3     [Easy course, The course itself is somewhat ea...               8237
# 4     [The only effect of this course is to add pres...               5790
# ...                                                 ...                ...
# 7437                                       [No reviews]                  0
# 7438                                       [No reviews]                  0
# 7439                                       [No reviews]                  0
# 7440                                       [No reviews]                  0
# 7441                                       [No reviews]                  0
#
#        Department
# 0            Math
# 1            Math
# 2            Math
# 3            Math
# 4            Coop
# ...           ...
# 7437  Environment
# 7438  Environment
# 7439       Health
# 7440  Engineering
# 7441  Engineering
#
# [7442 rows x 10 columns]

# %%
new_prof_df["Courses_Taught"] = new_prof_df["Courses_Taught"].apply(ast.literal_eval)
new_prof_df.head()
# Out:
#                Professor                   Courses_Taught  \
# 0            Aakar Gupta                         [CS 230]
# 1  Aaron Daniel Ettinger                       [PSCI 387]
# 2       Aaron Hutchinson                       [MATH 115]
# 3              Aaron Kay           [PSYCH 253, PSYCH 395]
# 4            Aaron Smith  [MATH 115, MATH 211, PMATH 467]
#
#                                    Professor_Reviews Liked_% Clear Engaging  \
# 0  [['TA was more clear and engaging', "Doesn't r...     20%   50%       0%
# 1  [["He knows his material and is not a strict p...     91%   NaN      NaN
# 2  [["There aren't any lectures this term, so I c...     90%  100%      75%
# 3  [['By far the best prof ive ever had. He is a ...     NaN   NaN      NaN
# 4  [["I believe our class was the first class he ...     80%   67%     100%
#
#   Number_of_Comments Number_of_Ratings liked
# 0         2 comments         2 ratings   20%
# 1                NaN               NaN   NaN
# 2          1 comment         2 ratings   90%
# 3         9 comments         0 ratings   NaN
# 4         4 comments         3 ratings   80%

# %% [markdown]
# We do the same thing for the professor table now, since a professor can teach courses of multiple departments, the code is modified slightly to handle that case

# %%
def generate_departments_prof(row, departments_dict):
    course_codes = set([course.split(" ")[0] for course in row['Courses_Taught']])
    
    departments = [dept for dept, codes in departments_dict.items() if course_codes & set(codes)]
    return set(departments)

new_prof_df['Department'] = new_prof_df.apply(generate_departments_prof, departments_dict=department, axis=1)
new_prof_df
# Out:
#                   Professor                   Courses_Taught  \
# 0               Aakar Gupta                         [CS 230]
# 1     Aaron Daniel Ettinger                       [PSCI 387]
# 2          Aaron Hutchinson                       [MATH 115]
# 3                 Aaron Kay           [PSYCH 253, PSYCH 395]
# 4               Aaron Smith  [MATH 115, MATH 211, PMATH 467]
# ...                     ...                              ...
# 3570         rebecca shantz                      [MUSIC 270]
# 3571       shahla Aliakbari           [AMATH 250, AMATH 351]
# 3572       shalah aliakbari                        [ECE 205]
# 3573                   tsen                       [CHEM 120]
# 3574          young ki yoon                         [NE 131]
#
#                                       Professor_Reviews Liked_% Clear  \
# 0     [['TA was more clear and engaging', "Doesn't r...     20%   50%
# 1     [["He knows his material and is not a strict p...     91%   NaN
# 2     [["There aren't any lectures this term, so I c...     90%  100%
# 3     [['By far the best prof ive ever had. He is a ...     NaN   NaN
# 4     [["I believe our class was the first class he ...     80%   67%
# ...                                                 ...     ...   ...
# 3570  [['She clearly outlines expectations before as...    100%  100%
# 3571  [['Assume everyone knows basic physics rules a...     47%   55%
# 3572  [['The professor makes very little effort in e...     31%   43%
# 3573  [["Very good prof considering I think he's new...    100%  100%
# 3574  [['Not that engaging, and not much detail on t...     82%   80%
#
#      Engaging Number_of_Comments Number_of_Ratings liked     Department
# 0          0%         2 comments         2 ratings   20%         {Math}
# 1         NaN                NaN               NaN   NaN      {Science}
# 2         75%          1 comment         2 ratings   90%         {Math}
# 3         NaN         9 comments         0 ratings   NaN         {Arts}
# 4        100%         4 comments         3 ratings   80%         {Math}
# ...       ...                ...               ...   ...            ...
# 3570     100%         2 comments         3 ratings  100%         {Arts}
# 3571      50%         6 comments        11 ratings   47%         {Math}
# 3572       0%          1 comment         7 ratings   31%  {Engineering}
# 3573     100%         2 comments         3 ratings  100%      {Science}
# 3574      80%         5 comments        10 ratings   82%  {Engineering}
#
# [3575 rows x 10 columns]

# %%
new_prof_df[new_prof_df.isnull().any(axis=1)]
# Out:
#                   Professor                  Courses_Taught  \
# 1     Aaron Daniel Ettinger                      [PSCI 387]
# 3                 Aaron Kay          [PSYCH 253, PSYCH 395]
# 5               Aazar Zafar                       [AFM 273]
# 8               Abdus Salam                      [ENGL 190]
# 14              Adam Amador                      [PORT 101]
# ...                     ...                             ...
# 3529              Yulia Gel  [MATH 235, STAT 331, STAT 443]
# 3530           Yun Hee Choi                      [STAT 331]
# 3535               Yutao Li                       [AFM 102]
# 3538          Yvette Kuiper                     [EARTH 238]
# 3558    Zinaida Gimpelevich  [RUSS 101, RUSS 102, RUSS 201]
#
#                                       Professor_Reviews Liked_% Clear  \
# 1     [["He knows his material and is not a strict p...     91%   NaN
# 3     [['By far the best prof ive ever had. He is a ...     NaN   NaN
# 5     [['Explained some concepts quite well using ex...     NaN   NaN
# 8     [["Professor Salam is excessively nit-picky, a...      0%    0%
# 14    [['He is very helpful with learning Portuguese...     NaN   NaN
# ...                                                 ...     ...   ...
# 3529  [['Beware...this prof said "I bite just not in...     NaN   NaN
# 3530  [["oh,my,she's beautiful and lovely.I pay most...     NaN   NaN
# 3535  [['Professor was difficult to understand and j...      0%    0%
# 3538  [["Yvette is such a cool person, one that you ...     NaN   NaN
# 3558  [["Zina is amazing. She gives out candy, marks...     NaN   NaN
#
#      Engaging Number_of_Comments Number_of_Ratings liked Department
# 1         NaN                NaN               NaN   NaN  {Science}
# 3         NaN         9 comments         0 ratings   NaN     {Arts}
# 5         NaN         5 comments         0 ratings   NaN     {Math}
# 8          0%         2 comments         2 ratings   NaN     {Arts}
# 14        NaN          1 comment         0 ratings   NaN     {Arts}
# ...       ...                ...               ...   ...        ...
# 3529      NaN        19 comments         0 ratings   NaN     {Math}
# 3530      NaN          1 comment         0 ratings   NaN     {Math}
# 3535       0%          1 comment          1 rating   NaN     {Math}
# 3538      NaN         2 comments         0 ratings   NaN  {Science}
# 3558      NaN        15 comments         0 ratings   NaN     {Arts}
#
# [825 rows x 10 columns]

# %% [markdown]
# Let's clean up the null values and also fix the formatting of some of the columns

# %%
def fill_null_by_ratings(row):
    if str(row["Number_of_Ratings"]).startswith('0'):
        row.fillna("0", inplace=True)
    return row

def fill_null_by_liked(row):
    if str(row["Liked_%"]).startswith("0"):
        row['liked'] = "0"
    return row
        
new_prof_df = new_prof_df.apply(fill_null_by_ratings, axis=1)
new_prof_df = new_prof_df.apply(fill_null_by_liked, axis=1)
new_prof_df[new_prof_df.isnull().any(axis=1)]
# Out:
#                         Professor  \
# 1           Aaron Daniel Ettinger
# 82          Alejandro Lopez-Ortiz
# 129                  Allan Cheyne
# 212               Andrew Thompson
# 454              Bruce R Hellinga
# 457                Bruce Richmond
# 599                Chris Springer
# 708               D'arcy Delamere
# 773                   Dave Devidi
# 783            David C.M. Dickson
# 784                  David Carter
# 842                     Deb Glebe
# 867            Derek Steinmoeller
# 922       Douglas William Andrews
# 937                Easwar Magesan
# 1006                  En-Hui Yang
# 1015                Eric Haldenby
# 1033       Erin Pauline O'Connell
# 1243            Hamid R. Tizhoosh
# 1316                  Hyun T. Kim
# 1319             Ian A.G Robinson
# 1351                J.C. Blokhuis
# 1352                  J.P. Pretti
# 1449           Jason Zi Yang Sham
# 1690   Jose Luis Jaimes-Dominguez
# 1729                Julie Messier
# 1918           Kristina Llewellyn
# 2003              Leroy J. Dickey
# 2019                      Lin Tan
# 2072  Lynch, Michael David Joseph
# 2076                M Anwar Hasan
# 2078                  M R Collins
# 2430                      N Zunic
# 2431                 Na Young Kim
# 2709                   Qiuqi Wang
# 2842                Robert Martin
# 2897     Rowland Keshena Robinson
# 2962              Sandra Campbell
# 3091         Shoja'eddin Chenouri
# 3106                   Simon Wood
# 3171                Stephen Brown
# 3204                  Steven Mock
# 3276                Terry O'Neill
#
#                                          Courses_Taught  \
# 1                                            [PSCI 387]
# 82    [CS 240, CS 341, CS 456, CS 234, CS 466, CS 44...
# 129                                         [PSYCH 101]
# 212                                [HIST 277, PSCI 282]
# 454                                          [CIVE 343]
# 457   [MATH 138, MATH 117, MATH 127, MATH 116, MATH ...
# 599    [STAT 230, STAT 231, STAT 211, ME 202, SYDE 213]
# 708                        [GBDA 102, AFM 280, ACC 690]
# 773                      [PHIL 145, PHIL 216, PHIL 100]
# 783                                         [ACTSC 331]
# 784                                 [AFM 101, PSCI 231]
# 842                                         [PSYCH 312]
# 867                                          [MATH 227]
# 922                                         [ACTSC 453]
# 937                                          [MATH 116]
# 1006                                 [ECE 318, ECE 203]
# 1015                                         [ARCH 143]
# 1033                               [GEOG 101, ENVS 195]
# 1243           [SYDE 223, SYDE 522, SYDE 201, SYDE 677]
# 1316                  [ACTSC 231, ACTSC 371, ACTSC 372]
# 1319                                        [VCULT 100]
# 1351                                         [SDS 210R]
# 1352                       [MATH 135, MATH 136, CS 116]
# 1449                               [MATH 135, MATH 136]
# 1690                                         [SPAN 101]
# 1729                                         [BIOL 359]
# 1918                                         [SDS 220R]
# 2003                                        [PMATH 360]
# 2019                           [SE 465, SE 201, SE 491]
# 2072                                         [BIOL 150]
# 2076                                          [ECE 222]
# 2078                           [ME 351, ME 250, ME 212]
# 2430  [PHIL 145, PHIL 100J, HUMSC 101, PHIL 219J, PH...
# 2431                                          [ECE 106]
# 2709                                        [ACTSC 371]
# 2842                                        [PMATH 332]
# 2897                                         [INDG 201]
# 2962                           [SOCWK 220R, SOCWK 365R]
# 3091  [STAT 230, STAT 231, STAT 330, STAT 444, STAT ...
# 3106                             [MUSIC 140, MUSIC 246]
# 3171                     [STAT 230, STAT 333, STAT 240]
# 3204                                [REC 280, HLTH 260]
# 3276                               [GBDA 101, GBDA 201]
#
#                                       Professor_Reviews Liked_% Clear  \
# 1     [["He knows his material and is not a strict p...     91%   NaN
# 82    [['knowledgeable and respectable, but his expl...     46%   NaN
# 129   [["Who says his lectures are boring??? I've ne...     NaN   NaN
# 212   [['Thompson\'s Canadian Legal History course i...     NaN   NaN
# 454   [['Really good prof. Really knowledgeable abou...     NaN   NaN
# 457   [['Ok guys this prof may not be the best teach...     NaN  100%
# 599   [['I studied the whole weekend for my 1st quiz...     NaN   NaN
# 708   [["He's one of the most intelligent profs I've...     76%   NaN
# 773   [["The lectures are by Dave, he's very nice an...     NaN  100%
# 783   [["He basically just reads off his notes in th...     30%   NaN
# 784   [['If you hate students, dont want to mark fai...     NaN   NaN
# 842   [['Used a lot of movies or videos to fill 3 hr...     NaN  100%
# 867   [['First time teaching, but did a great job. C...     NaN   NaN
# 922   [['Very nice Prof, always helps students. One ...     NaN   NaN
# 937   [["A good teacher, explains concepts well. I l...     NaN   NaN
# 1006  [['He made this course one of the most bird co...     50%   NaN
# 1015  [['quite self-centered with an extensive knowl...     NaN   NaN
# 1033  [["While I found the professor's lectures to b...     87%   NaN
# 1243  [['Engaging for the most part. Goes into tange...     82%   NaN
# 1316  [['nice guy', "He's a great guy but a TERRIBLE...     NaN   NaN
# 1319  [['I feel bad for this prof. He actually does ...     NaN   NaN
# 1351  [['Very nice and kind Professor. Gives feedbac...    100%   NaN
# 1352  [['J.P. makes this already great course even b...     93%   NaN
# 1449  [['so cute~love him~'], ['Provides clear notes...     NaN   NaN
# 1690  [["This guy seems like the kind of guy you'd w...     72%   NaN
# 1729  [['online biol 359, literally only very heard/...     NaN   NaN
# 1918  [["Prof Llewellyn does a good job at presentin...     NaN   NaN
# 2003  [['Lee definately loves Geometry. The problem ...     NaN   NaN
# 2019  [["Friendly prof who knows her stuff! She does...     68%   NaN
# 2072  [['tried to make things interesting, has a mon...     40%   NaN
# 2076  [['Not to be confused with other professors na...     32%   NaN
# 2078  [["Great prof, had him for Thermo 2. His notes...    100%   NaN
# 2430  [["Personally, I find him to be very clear in ...      8%   NaN
# 2431  [['Na is passionate about the content she is t...     47%   NaN
# 2709  [["In the beginning, I was quite excited about...     NaN   NaN
# 2842  [['Some of the board work was a little disorga...     NaN   NaN
# 2897  [["i had his class online, we had a synchronou...     90%   NaN
# 2962  [["I am very frustrated with this professor. I...     NaN   NaN
# 3091  [["His Note are fine, but the details he wrote...     33%   NaN
# 3106  [['Literally born to teach. Funny, engaging, k...     98%   NaN
# 3171  [['Quirky, but still quite boring. Sometimes r...     NaN   NaN
# 3204  [['WORST PROF. he is very inconsiderate and is...     NaN   NaN
# 3276  [["Laidback and engaging. Looks forward to stu...     86%   NaN
#
#      Engaging Number_of_Comments Number_of_Ratings liked           Department
# 1         NaN                NaN               NaN   NaN            {Science}
# 82        NaN        47 comments        23 ratings   NaN               {Math}
# 129       NaN        12 comments          1 rating   NaN               {Arts}
# 212       NaN         2 comments          1 rating   NaN      {Arts, Science}
# 454      100%         4 comments          1 rating   NaN        {Engineering}
# 457       NaN        39 comments          1 rating   NaN               {Math}
# 599       NaN        57 comments          1 rating   NaN  {Engineering, Math}
# 708       NaN                NaN               NaN   NaN         {Arts, Math}
# 773       NaN         7 comments         2 ratings   NaN               {Arts}
# 783       NaN                NaN               NaN   NaN               {Math}
# 784       NaN        18 comments          1 rating   NaN      {Math, Science}
# 842       NaN          1 comment          1 rating   NaN               {Arts}
# 867       NaN          1 comment          1 rating   NaN               {Math}
# 922       NaN          1 comment          1 rating   NaN               {Math}
# 937        0%          1 comment          1 rating   NaN               {Math}
# 1006      NaN         7 comments          1 rating   NaN        {Engineering}
# 1015      NaN         4 comments          1 rating   NaN        {Engineering}
# 1033      NaN                NaN               NaN   NaN        {Environment}
# 1243      NaN                NaN               NaN   NaN        {Engineering}
# 1316      NaN                NaN               NaN   NaN               {Math}
# 1319      NaN                NaN               NaN   NaN               {Arts}
# 1351      NaN                NaN               NaN   NaN               {Arts}
# 1352      NaN                NaN               NaN   NaN               {Math}
# 1449      NaN                NaN               NaN   NaN               {Math}
# 1690      NaN                NaN               NaN   NaN               {Arts}
# 1729      NaN          1 comment         3 ratings   NaN            {Science}
# 1918      NaN         2 comments          1 rating   NaN               {Arts}
# 2003      NaN         6 comments          1 rating   NaN               {Math}
# 2019      63%        11 comments        30 ratings   68%        {Engineering}
# 2072      NaN                NaN               NaN   NaN            {Science}
# 2076      NaN        27 comments         5 ratings   32%        {Engineering}
# 2078      NaN         7 comments         2 ratings  100%        {Engineering}
# 2430      NaN        44 comments         6 ratings    8%      {Arts, Science}
# 2431      50%          1 comment         6 ratings   47%        {Engineering}
# 2709      NaN          1 comment          1 rating   NaN               {Math}
# 2842     100%          1 comment          1 rating   NaN               {Math}
# 2897      NaN          1 comment          1 rating   90%               {Arts}
# 2962      NaN         4 comments          1 rating   NaN               {Arts}
# 3091      NaN                NaN               NaN   NaN               {Math}
# 3106      98%       143 comments       179 ratings   98%               {Arts}
# 3171      NaN         3 comments          1 rating   NaN               {Math}
# 3204      NaN         2 comments          1 rating   NaN             {Health}
# 3276      NaN                NaN               NaN   NaN               {Arts}

# %% [markdown]
# Only a few values so I'll just drop them since it won't affect the data significantly

# %%
new_prof_df = new_prof_df.dropna(how='any', axis=0)
new_prof_df.reset_index()
new_prof_df
# Out:
#              Professor                   Courses_Taught  \
# 0          Aakar Gupta                         [CS 230]
# 2     Aaron Hutchinson                       [MATH 115]
# 3            Aaron Kay           [PSYCH 253, PSYCH 395]
# 4          Aaron Smith  [MATH 115, MATH 211, PMATH 467]
# 5          Aazar Zafar                        [AFM 273]
# ...                ...                              ...
# 3570    rebecca shantz                      [MUSIC 270]
# 3571  shahla Aliakbari           [AMATH 250, AMATH 351]
# 3572  shalah aliakbari                        [ECE 205]
# 3573              tsen                       [CHEM 120]
# 3574     young ki yoon                         [NE 131]
#
#                                       Professor_Reviews Liked_% Clear  \
# 0     [['TA was more clear and engaging', "Doesn't r...     20%   50%
# 2     [["There aren't any lectures this term, so I c...     90%  100%
# 3     [['By far the best prof ive ever had. He is a ...       0     0
# 4     [["I believe our class was the first class he ...     80%   67%
# 5     [['Explained some concepts quite well using ex...       0     0
# ...                                                 ...     ...   ...
# 3570  [['She clearly outlines expectations before as...    100%  100%
# 3571  [['Assume everyone knows basic physics rules a...     47%   55%
# 3572  [['The professor makes very little effort in e...     31%   43%
# 3573  [["Very good prof considering I think he's new...    100%  100%
# 3574  [['Not that engaging, and not much detail on t...     82%   80%
#
#      Engaging Number_of_Comments Number_of_Ratings liked     Department
# 0          0%         2 comments         2 ratings   20%         {Math}
# 2         75%          1 comment         2 ratings   90%         {Math}
# 3           0         9 comments         0 ratings     0         {Arts}
# 4        100%         4 comments         3 ratings   80%         {Math}
# 5           0         5 comments         0 ratings     0         {Math}
# ...       ...                ...               ...   ...            ...
# 3570     100%         2 comments         3 ratings  100%         {Arts}
# 3571      50%         6 comments        11 ratings   47%         {Math}
# 3572       0%          1 comment         7 ratings   31%  {Engineering}
# 3573     100%         2 comments         3 ratings  100%      {Science}
# 3574      80%         5 comments        10 ratings   82%  {Engineering}
#
# [3532 rows x 10 columns]

# %% [markdown]
# Here we change the percentages to their actual values with respect to the number of ratings

# %%
new_prof_df["Number_of_Comments"] = new_prof_df["Number_of_Comments"].apply(lambda x: x.split(" ")[0])
new_prof_df["Number_of_Ratings"] = new_prof_df["Number_of_Ratings"].apply(lambda x: x.split(" ")[0])
def convert_percentage(row, col):
    val = (int(str(row[col]).replace("%", ""))/100) * int(row["Number_of_Ratings"])
    row[col] = round(val)
    return row
for col in ["Liked_%", "Clear", "Engaging"]:
    new_prof_df = new_prof_df.apply(convert_percentage, col=col, axis=1)

new_prof_df = new_prof_df.drop('liked', axis=1)
new_prof_df
# Out:
#              Professor                   Courses_Taught  \
# 0          Aakar Gupta                         [CS 230]
# 2     Aaron Hutchinson                       [MATH 115]
# 3            Aaron Kay           [PSYCH 253, PSYCH 395]
# 4          Aaron Smith  [MATH 115, MATH 211, PMATH 467]
# 5          Aazar Zafar                        [AFM 273]
# ...                ...                              ...
# 3570    rebecca shantz                      [MUSIC 270]
# 3571  shahla Aliakbari           [AMATH 250, AMATH 351]
# 3572  shalah aliakbari                        [ECE 205]
# 3573              tsen                       [CHEM 120]
# 3574     young ki yoon                         [NE 131]
#
#                                       Professor_Reviews  Liked_%  Clear  \
# 0     [['TA was more clear and engaging', "Doesn't r...        0      1
# 2     [["There aren't any lectures this term, so I c...        2      2
# 3     [['By far the best prof ive ever had. He is a ...        0      0
# 4     [["I believe our class was the first class he ...        2      2
# 5     [['Explained some concepts quite well using ex...        0      0
# ...                                                 ...      ...    ...
# 3570  [['She clearly outlines expectations before as...        3      3
# 3571  [['Assume everyone knows basic physics rules a...        5      6
# 3572  [['The professor makes very little effort in e...        2      3
# 3573  [["Very good prof considering I think he's new...        3      3
# 3574  [['Not that engaging, and not much detail on t...        8      8
#
#       Engaging Number_of_Comments Number_of_Ratings     Department
# 0            0                  2                 2         {Math}
# 2            2                  1                 2         {Math}
# 3            0                  9                 0         {Arts}
# 4            3                  4                 3         {Math}
# 5            0                  5                 0         {Math}
# ...        ...                ...               ...            ...
# 3570         3                  2                 3         {Arts}
# 3571         6                  6                11         {Math}
# 3572         0                  1                 7  {Engineering}
# 3573         3                  2                 3      {Science}
# 3574         8                  5                10  {Engineering}
#
# [3532 rows x 9 columns]

# %% [markdown]
# The tables have been cleaned, now we can move on to the data visualization

# %%
course_df.to_csv("./data files/Cleaned/cleaned_course_data.csv", index=False)
new_prof_df.to_csv("./data files/Cleaned/cleaned_prof_data.csv", index=False)

# %% [markdown]
# # Differences (Raw vs Clean)

# %% [markdown]
# ### Course table

# %%
pd.read_csv("./Course_data.csv").head(5)
# Out:
#   Course_Code                         Course_Name  Number_of_Ratings  \
# 0      CS 115  Introduction to Computer Science 1               2206
# 1    MATH 135     Algebra for Honours Mathematics               1555
# 2    ECON 101      Introduction to Microeconomics               1398
# 3   PSYCH 101             Introductory Psychology               1084
# 4    MATH 137  Calculus 1 for Honours Mathematics               1036
#
#   Number_of_Comments Useful Easy Liked  \
# 0                NaN    22%  11%   25%
# 1       338 comments    84%  43%   78%
# 2       264 comments    63%  70%   45%
# 3       229 comments    73%  66%   78%
# 4       211 comments    84%  56%   68%
#
#                                       Course_Reviews  \
# 0  ['A bird course, easy to get 90+, but it is us...
# 1  ['Very easy and interesting course, no concept...
# 2  ['you can just google everything but its just ...
# 3  ["Super fun, engaging prof and the exams are l...
# 4  ['Easy course', 'The course itself is somewhat...
#
#                                    Course_Enrollment
# 0  ['87/90', '83/90', '88/90', '68/90', '88/90', ...
# 1  ['55/60', '54/60', '52/60', '59/60', '52/60', ...
# 2  ['252/387', '364/387', '184/220', '189/220', '...
# 3  ['418/446', '430/446', '212/285', '142/160', '...
# 4  ['92/120', '93/120', '111/120', '104/120', '92...

# %%
course_df.head(5)
# Out:
#   Course_Code                         Course_Name  Number_of_Ratings  \
# 0      CS 115  Introduction to Computer Science 1               2206
# 1    MATH 135     Algebra for Honours Mathematics               1555
# 2    ECON 101      Introduction to Microeconomics               1398
# 3    MATH 137  Calculus 1 for Honours Mathematics               1036
# 4        PD 1                 Career Fundamentals               1000
#
#   Number_of_Comments Useful Easy Liked  \
# 0                114    485  243   552
# 1                338   1306  669  1213
# 2                264    881  979   629
# 3                211    870  580   704
# 4                189    190  800    70
#
#                                       Course_Reviews  Course_Enrollment  \
# 0  [A bird course, easy to get 90+, but it is use...               4359
# 1  [Very easy and interesting course, no concepts...               7597
# 2  [you can just google everything but its just f...               6247
# 3  [Easy course, The course itself is somewhat ea...               8237
# 4  [The only effect of this course is to add pres...               5790
#
#   Department
# 0       Math
# 1       Math
# 2       Math
# 3       Math
# 4       Coop

# %% [markdown]
# ### Professor table

# %%
pd.read_csv("./Prof_data.csv").head(5)
# Out:
#        Professor_Name  Course Liked_%  \
# 0  Lori Michelle Case  CS 115     77%
# 1     Naomi Nishimura  CS 115     70%
# 2         Troy Vasiga  CS 115     96%
# 3   Victoria Sakhnini  CS 115     85%
# 4        Sandy Graham  CS 115     74%
#
#                                    Professor_Reviews
# 0  ['clear prof', 'Lori is an awesome professor. ...
# 1  ['Not really engaging but helpful.', 'Definite...
# 2  ['One of the best CS teacher, his lecture is v...
# 3  ['Great prof. Explains concepts very well and ...
# 4  ['Clear in her explanations.', "Her clicker so...

# %%
new_prof_df.head(5)
# Out:
#           Professor                   Courses_Taught  \
# 0       Aakar Gupta                         [CS 230]
# 2  Aaron Hutchinson                       [MATH 115]
# 3         Aaron Kay           [PSYCH 253, PSYCH 395]
# 4       Aaron Smith  [MATH 115, MATH 211, PMATH 467]
# 5       Aazar Zafar                        [AFM 273]
#
#                                    Professor_Reviews  Liked_%  Clear  \
# 0  [['TA was more clear and engaging', "Doesn't r...        0      1
# 2  [["There aren't any lectures this term, so I c...        2      2
# 3  [['By far the best prof ive ever had. He is a ...        0      0
# 4  [["I believe our class was the first class he ...        2      2
# 5  [['Explained some concepts quite well using ex...        0      0
#
#    Engaging Number_of_Comments Number_of_Ratings Department
# 0         0                  2                 2     {Math}
# 2         2                  1                 2     {Math}
# 3         0                  9                 0     {Arts}
# 4         3                  4                 3     {Math}
# 5         0                  5                 0     {Math}
